# %%
#Nama : Khanif Fauzi Pambudi

import pandas as pd
import numpy as np

df = pd.read_csv('https://drive.google.com/file/d/1gYIDXXbDdNloNbAb2bOf1up1HUexOwa3/view?usp=sharing') #membaca dataset dengan menggunakan pandas

class VIRP:
  def __init__(self, V = 0, I = 0, R = 0, P = 0): #identifikasi parameter V, I, R, P
    self.V = V
    self.I = I
    self.R = R
    self.P = P

  def hitungV(self): #fungsi menghitung nilai V
    return self.R * self.I
  def hitungI(self): #fungsi menghitung nilai I
    return self.V / self.R 
  def hitungR(self): #fungsi menghitung nilai R
    return self.V / self.I 
  def hitungP(self): #fungsi menghitung nilai P
    return self.V * self.I 

loop = True
while loop:
  menu : """
    Menghitung V, I, R, P
    (1) Menghitung V 
    (2) Menghitung I
    (3) Menghitung R
    (4) Menghitung P
    (5) Selesai Menghitung

  pilihlah (1-5): """

  try:
    pilihan = input(menu)
  except:
    pilihan = 0
    
  if pilihan not in range (1,6):      #kondisi jika input tidak dalam satu range akan muncul pilihan
    print
    print("pilih 1, 2, 3, 4, 5")
  elif pilihan in range (1,5):        #kondisi jika input dalam satu range maka akan memproses sesuai perintah pilihan
    if pilihan == 1:                  #memproses perhitungan Volt(V)
      print
      print("Menghitung V")
      R = input("input hambatan(R)= ")
      I = input("input arus (I)= ")
      P = 0
      V = VIRP(0, I, R, P)
      print("nilai V= ",V.hitungV())
    elif pilihan == 2:                #memproses perhitungan arus (I)
      print
      print("Mengitung I")
      V = input("input volt(V)= ")
      R = input("input hambatan(R)= ")
      P = 0
      I = VIRP(V, 0, I, P)
      print("nilai I= ",I.hitungI())
    elif pilihan == 3:                #memproses perhitungan hambatan(R)
      print
      print("Menghitung R")
      V = input("input volt(V)= ")
      I = input("input arus(I)= ")
      P = 0
      R = VIRP(V, I, 0, 0)
      print("nilai R= ", R.hitungR())
    else:                            #memproses perhitungan daya (P)
      print
      print("Menghitung P")
      V = input("input volt(V)= ")
      I = input("input arus(I)= ")
      R = 0
      P = VIRP(V, I, R, 0)
      print("nilai P= ", P.hitungP())

      raw_input('tekan enter untuk melanjutkan')
  else:
    loop = False
# Out:
# Streaming output truncated to the last 5000 lines.
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# pilih 1, 2, 3, 4, 5
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('NMC1-9')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-b6aef150477b> in <module>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_excel('NMC1-9')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# ...
